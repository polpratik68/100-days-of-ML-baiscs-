# %% [markdown]
# # Basic visualization

# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('iris.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
# matplot visualization

# %%
import matplotlib.pyplot as plt 
df1 = df[df['species']=='setosa']
df2 = df[df['species']=='versicolor']
plt.scatter(df1['sepal_length'],df1['sepal_width'],color='r',marker='*')
plt.scatter(df2['sepal_length'],df2['sepal_width'],color='b',marker='*')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df1 = df[df['species']=='setosa']
df2 = df[df['species']=='versicolor']
plt.scatter(df1['sepal_length'],df1['sepal_width'],color='r',marker='*')
plt.scatter(df2['sepal_length'],df2['sepal_width'],color='g',marker='*')
plt.show()

# %%
list1=['class9','class10','class11','class12']
school1=[34,24,49,47]

# %%
plt.pie(school1,labels=list1,radius=1.4)
plt.show()

# %%
# subplot

# %%
plt.subplot(2,2,1)
plt.pie([1,1])
plt.subplot(2,2,2)
plt.bar(list1,school1)
plt.subplot(2,2,3)
plt.pie([1,2,3,4])
plt.scatter(list1,school1)
plt.subplot(2,2,4)
plt.show()

# %%
plt.pie([1,2,3])
plt.savefig('mychart.png')

# %%
# seaborn visualization

# %%
# seaborn advanced data visuallization library good for statistical analysis built on top of matplotlib and pandas

# %%
import seaborn as sns

# %%
list1 = ['class9','class10','class11','class12']
school1 = [34,24,49,47]

# %%
# to check default datasets 
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# to check how many categories present in particular column 
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
# line chart 
sns.lineplot(x='size',y='total_bill',data=df)
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.lineplot(x='tip',y='total_bill',data=df)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.lineplot(x='size',y='total_bill',data=df,hue='sex')
plt.title('bill')
plt.show()

# %%
sns.lineplot(x='size',y='total_bill',data=df,hue='day')
plt.plot('bill')
plt.show()

# %%
sns.lineplot(x='size',y='total_bill',data=df,hue='smoker')
plt.title('bill')
plt.show()

# %%
sns.lineplot(x='size',y='total_bill',data=df,hue='smoker')
plt.title('bill')
plt.show()

# %%
sns.histplot(x='size',y='total_bill',data=df,hue='size')
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
sns.kdeplot(df, shade=True)
# Out:
# <Axes: ylabel='Density'>

# %%
# bar bplot 
sns.barplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',data=df,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',data=df,hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.histplot(x='day',y='total_bill',data=df,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.scatterplot(x='day',y='total_bill',data=df,hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.scatterplot(x='size',y='total_bill',data=df,hue='smoker')
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
# load another data set 
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=df,hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x='petal_length',y='petal_width',data=df,hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
# heatmap 
# heatmap is a graphical representaion of 2d 
# each value is represented in matrix and it has special color

# %%
import numpy as np 
a=np.random.randint(200,208,(3,3))
a
# Out:
# array([[207, 202, 200],
#        [206, 201, 203],
#        [200, 202, 200]])

# %%
sns.heatmap(a)
# Out:
# <Axes: >

# %%
sns.heatmap(a,annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(a,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
# pairplot 
sns.pairplot(df)
