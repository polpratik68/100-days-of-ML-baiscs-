# %% [markdown]
# # starting code

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np

# %%
df=pd.read_csv('students.csv')
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df.head(5) # top 5 rows
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# 4                 0          75

# %%
df.shape
# Out:
# (10, 7)

# %%
df.size
# Out:
# 70

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
# to check columns name 
df.columns
# Out:
# Index(['Student ID', 'Class', 'Study hrs', 'Sleeping hrs',
#        'Social Media usage hrs', 'Mobile Games hrs', 'Percantege'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1001,   10,    2,    9,    3,    5,   50],
#        [1002,   10,    6,    8,    2,    0,   80],
#        [1003,   10,    3,    8,    2,    4,   60],
#        [1004,   11,    0,   10,    1,    5,   45],
#        [1005,   11,    4,    7,    2,    0,   75],
#        [1006,   11,   10,    7,    0,    0,   96],
#        [1007,   12,    4,    6,    0,    0,   80],
#        [1008,   12,   10,    6,    2,    0,   90],
#        [1009,   12,    2,    8,    2,    4,   60],
#        [1010,   12,    6,    9,    1,    0,   85]], dtype=int64)

# %%
df.dtypes
# Out:
# Student ID                int64
# Class                     int64
# Study hrs                 int64
# Sleeping hrs              int64
# Social Media usage hrs    int64
# Mobile Games hrs          int64
# Percantege                int64
# dtype: object

# %%
df.size
# Out:
# 70

# %%
df['Class']
# Out:
# 0    10
# 1    10
# 2    10
# 3    11
# 4    11
# 5    11
# 6    12
# 7    12
# 8    12
# 9    12
# Name: Class, dtype: int64

# %%
# to check stats info 
df.describe ()
# Out:
#        Student ID      Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# count    10.00000  10.000000     10.000     10.000000               10.000000
# mean   1005.50000  11.100000      4.700      7.800000                1.500000
# std       3.02765   0.875595      3.335      1.316561                0.971825
# min    1001.00000  10.000000      0.000      6.000000                0.000000
# 25%    1003.25000  10.250000      2.250      7.000000                1.000000
# 50%    1005.50000  11.000000      4.000      8.000000                2.000000
# 75%    1007.75000  12.000000      6.000      8.750000                2.000000
# max    1010.00000  12.000000     10.000     10.000000                3.000000
#
#        Mobile Games hrs  Percantege
# count         10.000000   10.000000
# mean           1.800000   72.100000
# std            2.347576   17.342626
# min            0.000000   45.000000
# 25%            0.000000   60.000000
# 50%            0.000000   77.500000
# ...

# %%
# here min percentage is 45 andmax is 96

# %%
df.mean()
# Out:
# Student ID                1005.5
# Class                       11.1
# Study hrs                    4.7
# Sleeping hrs                 7.8
# Social Media usage hrs       1.5
# Mobile Games hrs             1.8
# Percantege                  72.1
# dtype: float64

# %%
# findout particular columns mean value 
df['Class'].mean()
# Out:
# 11.1

# %%
# standard deviation 
df.std()
# Out:
# Student ID                 3.027650
# Class                      0.875595
# Study hrs                  3.335000
# Sleeping hrs               1.316561
# Social Media usage hrs     0.971825
# Mobile Games hrs           2.347576
# Percantege                17.342626
# dtype: float64

# %%
# to find out particular columns std 
df['Class'].std()
# Out:
# 0.8755950357709131

# %%
df.quantile()
# Out:
# Student ID                1005.5
# Class                       11.0
# Study hrs                    4.0
# Sleeping hrs                 8.0
# Social Media usage hrs       2.0
# Mobile Games hrs             0.0
# Percantege                  77.5
# Name: 0.5, dtype: float64

# %%
df['Percantege'].quantile()
# Out:
# 77.5

# %%
df.quantile(0.75)
# Out:
# Student ID                1007.75
# Class                       12.00
# Study hrs                    6.00
# Sleeping hrs                 8.75
# Social Media usage hrs       2.00
# Mobile Games hrs             4.00
# Percantege                  83.75
# Name: 0.75, dtype: float64

# %%
df.mode()
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001   12.0        2.0           8.0                     2.0
# 1        1002    NaN        4.0           NaN                     NaN
# 2        1003    NaN        6.0           NaN                     NaN
# 3        1004    NaN       10.0           NaN                     NaN
# 4        1005    NaN        NaN           NaN                     NaN
# 5        1006    NaN        NaN           NaN                     NaN
# 6        1007    NaN        NaN           NaN                     NaN
# 7        1008    NaN        NaN           NaN                     NaN
# 8        1009    NaN        NaN           NaN                     NaN
# 9        1010    NaN        NaN           NaN                     NaN
#
#    Mobile Games hrs  Percantege
# 0               0.0        60.0
# 1               NaN        80.0
# 2               NaN         NaN
# 3               NaN         NaN
# ...

# %%
df['Percantege'].mode()
# Out:
# 0    60
# 1    80
# Name: Percantege, dtype: int64

# %%
df.var()
# Out:
# Student ID                  9.166667
# Class                       0.766667
# Study hrs                  11.122222
# Sleeping hrs                1.733333
# Social Media usage hrs      0.944444
# Mobile Games hrs            5.511111
# Percantege                300.766667
# dtype: float64

# %%
df['Class'].var()
# Out:
# 0.7666666666666666

# %%
df.corr()
# Out:
#                         Student ID     Class  Study hrs  Sleeping hrs  \
# Student ID                1.000000  0.943042   0.335626     -0.306622
# Class                     0.943042  1.000000   0.239717     -0.366266
# Study hrs                 0.335626  0.239717   1.000000     -0.622524
# Sleeping hrs             -0.306622 -0.366266  -0.622524      1.000000
# Social Media usage hrs   -0.434272 -0.457019  -0.291402      0.260525
# Mobile Games hrs         -0.406449 -0.367573  -0.774881      0.668667
# Percantege                0.477181  0.387075   0.924619     -0.690046
#
#                         Social Media usage hrs  Mobile Games hrs  Percantege
# Student ID                           -0.434272         -0.406449    0.477181
# Class                                -0.457019         -0.367573    0.387075
# Study hrs                            -0.291402         -0.774881    0.924619
# Sleeping hrs                          0.260525          0.668667   -0.690046
# ...

# %%
df.corr(method='pearson')
# Out:
#                         Student ID     Class  Study hrs  Sleeping hrs  \
# Student ID                1.000000  0.943042   0.335626     -0.306622
# Class                     0.943042  1.000000   0.239717     -0.366266
# Study hrs                 0.335626  0.239717   1.000000     -0.622524
# Sleeping hrs             -0.306622 -0.366266  -0.622524      1.000000
# Social Media usage hrs   -0.434272 -0.457019  -0.291402      0.260525
# Mobile Games hrs         -0.406449 -0.367573  -0.774881      0.668667
# Percantege                0.477181  0.387075   0.924619     -0.690046
#
#                         Social Media usage hrs  Mobile Games hrs  Percantege
# Student ID                           -0.434272         -0.406449    0.477181
# Class                                -0.457019         -0.367573    0.387075
# Study hrs                            -0.291402         -0.774881    0.924619
# Sleeping hrs                          0.260525          0.668667   -0.690046
# ...

# %%
df.cov()
# Out:
#                         Student ID     Class  Study hrs  Sleeping hrs  \
# Student ID                9.166667  2.500000   3.388889     -1.222222
# Class                     2.500000  0.766667   0.700000     -0.422222
# Study hrs                 3.388889  0.700000  11.122222     -2.733333
# Sleeping hrs             -1.222222 -0.422222  -2.733333      1.733333
# Social Media usage hrs   -1.277778 -0.388889  -0.944444      0.333333
# Mobile Games hrs         -2.888889 -0.755556  -6.066667      2.066667
# Percantege               25.055556  5.877778  53.477778    -15.755556
#
#                         Social Media usage hrs  Mobile Games hrs  Percantege
# Student ID                           -1.277778         -2.888889   25.055556
# Class                                -0.388889         -0.755556    5.877778
# Study hrs                            -0.944444         -6.066667   53.477778
# Sleeping hrs                          0.333333          2.066667  -15.755556
# ...

# %%
# indexing ? slicing of dataframe 
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df['Class']
# Out:
# 0    10
# 1    10
# 2    10
# 3    11
# 4    11
# 5    11
# 6    12
# 7    12
# 8    12
# 9    12
# Name: Class, dtype: int64

# %%
# we have to create 2d array
df[['Class']]
# Out:
#    Class
# 0     10
# 1     10
# 2     10
# 3     11
# 4     11
# 5     11
# 6     12
# 7     12
# 8     12
# 9     12

# %%
df1=df[['Class','Percantege']]

# %%
df1
# Out:
#    Class  Percantege
# 0     10          50
# 1     10          80
# 2     10          60
# 3     11          45
# 4     11          75
# 5     11          96
# 6     12          80
# 7     12          90
# 8     12          60
# 9     12          85

# %%
# loc method ....labelled basedmethod 
df.loc[0:3,'Class':'Percantege']
# Out:
#    Class  Study hrs  Sleeping hrs  Social Media usage hrs  Mobile Games hrs  \
# 0     10          2             9                       3                 5
# 1     10          6             8                       2                 0
# 2     10          3             8                       2                 4
# 3     11          0            10                       1                 5
#
#    Percantege
# 0          50
# 1          80
# 2          60
# 3          45

# %%
 df.loc[:,'Class':'Percantege']
# Out:
#    Class  Study hrs  Sleeping hrs  Social Media usage hrs  Mobile Games hrs  \
# 0     10          2             9                       3                 5
# 1     10          6             8                       2                 0
# 2     10          3             8                       2                 4
# 3     11          0            10                       1                 5
# 4     11          4             7                       2                 0
# 5     11         10             7                       0                 0
# 6     12          4             6                       0                 0
# 7     12         10             6                       2                 0
# 8     12          2             8                       2                 4
# 9     12          6             9                       1                 0
#
#    Percantege
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96
# 6          80
# ...

# %%
df.loc[5:,'Class':'Percantege']
# Out:
#    Class  Study hrs  Sleeping hrs  Social Media usage hrs  Mobile Games hrs  \
# 5     11         10             7                       0                 0
# 6     12          4             6                       0                 0
# 7     12         10             6                       2                 0
# 8     12          2             8                       2                 4
# 9     12          6             9                       1                 0
#
#    Percantege
# 5          96
# 6          80
# 7          90
# 8          60
# 9          85

# %%
df.loc[:5,'Class':'Percantege']
# Out:
#    Class  Study hrs  Sleeping hrs  Social Media usage hrs  Mobile Games hrs  \
# 0     10          2             9                       3                 5
# 1     10          6             8                       2                 0
# 2     10          3             8                       2                 4
# 3     11          0            10                       1                 5
# 4     11          4             7                       2                 0
# 5     11         10             7                       0                 0
#
#    Percantege
# 0          50
# 1          80
# 2          60
# 3          45
# 4          75
# 5          96

# %%
df[df['Class']==10]
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60

# %%
df[df['Class']==11]
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
#
#    Mobile Games hrs  Percantege
# 3                 5          45
# 4                 0          75
# 5                 0          96

# %%
df[df['Class']==12]
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 6                 0          80
# 7                 0          90
# 8                 4          60
# 9                 0          85

# %%
df[(df['Percantege']>50) & (df['Percantege']<80)]
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 2        1003     10          3             8                       2
# 4        1005     11          4             7                       2
# 8        1009     12          2             8                       2
#
#    Mobile Games hrs  Percantege
# 2                 4          60
# 4                 0          75
# 8                 4          60

# %%
df[(df['Percantege']>50) & (df['Percantege']<80)]
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 2        1003     10          3             8                       2
# 4        1005     11          4             7                       2
# 8        1009     12          2             8                       2
#
#    Mobile Games hrs  Percantege
# 2                 4          60
# 4                 0          75
# 8                 4          60

# %%
df[(df['Percantege']>30)& (df['Percantege']<80)]
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 8        1009     12          2             8                       2
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 2                 4          60
# 3                 5          45
# 4                 0          75
# 8                 4          60

# %%
df.loc[df['Class']==10,['Class','Percantege','Social Media usage hrs']]
# Out:
#    Class  Percantege  Social Media usage hrs
# 0     10          50                       3
# 1     10          80                       2
# 2     10          60                       2
